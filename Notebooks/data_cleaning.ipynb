# %% [markdown]
# # 🌦️ Weather Trend Forecasting
#
# ## PM Accelerator Technical Assessment
#
# ### Objective
# The objective of this project is to analyze the **Global Weather Repository** dataset and forecast future weather trends using Machine Learning and Time Series Analysis.
#
# This project covers:
#
# - Data Cleaning & Preprocessing
# - Exploratory Data Analysis (EDA)
# - Time Series Forecasting
# - Model Evaluation
# - Insights and Conclusions
#
# ---
#
# **Dataset**
#
# Global Weather Repository (Daily Updating)
#
# The dataset contains daily weather observations from cities around the world, including over 40 weather-related features such as:
#
# - Temperature
# - Humidity
# - Wind Speed
# - Pressure
# - Visibility
# - Air Quality
# - Precipitation
#
# The dataset is updated daily and is suitable for weather forecasting and climate trend analysis.
#
# ---

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('Dataset/GlobalWeatherRepository.csv')

# %%
df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
df.shape
# Out:
# (149880, 41)

# %%
df.columns
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149880 entries, 0 to 149879
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       149880 non-null  object
#  1   location_name                 149880 non-null  object
#  2   latitude                      149880 non-null  float64
#  3   longitude                     149880 non-null  float64
#  4   timezone                      149880 non-null  object
#  5   last_updated_epoch            149880 non-null  int64
#  6   last_updated                  149880 non-null  object
#  7   temperature_celsius           149880 non-null  float64
#  8   temperature_fahrenheit        149880 non-null  float64
#  9   condition_text                149880 non-null  object
#  10  wind_mph                      149880 non-null  float64
#  11  wind_kph                      149880 non-null  float64
# ...

# %%
df.describe()
# Out:
#             latitude      longitude  last_updated_epoch  temperature_celsius  \
# count  149880.000000  149880.000000        1.498800e+05        149880.000000
# mean       19.233784      21.899291        1.749207e+09            21.313501
# std        24.403834      65.779640        1.925660e+07             9.532220
# min       -41.300000    -175.200000        1.715849e+09           -29.800000
# 25%         4.050300      -6.836100        1.732611e+09            16.000000
# 50%        17.250000      23.236100        1.749200e+09            23.600000
# 75%        40.400000      49.882200        1.765784e+09            27.900000
# max        65.300000     179.220000        1.782540e+09            79.300000
#
#        temperature_fahrenheit       wind_mph       wind_kph    wind_degree  \
# count           149880.000000  149880.000000  149880.000000  149880.000000
# mean                70.366088       7.947467      12.793991     169.308467
# ...

# %% [markdown]
# # Handling Missing Value

# %%
df.isnull().sum()
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# ...

# %%
df = df.dropna()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (149880, 41)

# %%
df['last_updated'] = pd.to_datetime(df['last_updated'])
df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch        last_updated  temperature_celsius  \
# 0          1715849100 2024-05-16 13:15:00                 26.6
# 1          1715849100 2024-05-16 10:45:00                 19.0
# 2          1715849100 2024-05-16 09:45:00                 23.0
# 3          1715849100 2024-05-16 10:45:00                  6.3
# 4          1715849100 2024-05-16 09:45:00                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
df["last_updated"] = pd.to_datetime(df["last_updated"])

# %%
df["year"] = df["last_updated"].dt.year
df["month"] = df["last_updated"].dt.month
df["day"] = df["last_updated"].dt.day
df["dayofweek"] = df["last_updated"].dt.dayofweek
df["dayofyear"] = df["last_updated"].dt.dayofyear

# %%
final_df = df
final_df.to_csv("Dataset/cleaned_dataset.csv", index=False)
